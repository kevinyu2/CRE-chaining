# %%
from pycaret.clustering import *
import pandas as pd

# %%
embedding = pd.read_csv("mds_embedding_1500.csv", header=None).drop(0, axis=1)
embedding_sample = embedding.sample(1000)
s = setup(embedding_sample)
# Out:
# <style type="text/css">
# #T_87178_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_87178">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87178_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_87178_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87178_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_87178_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_87178_row0_col1" class="data row0 col1" >2036</td>
#     </tr>
#     <tr>
#       <th id="T_87178_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_87178_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_87178_row1_col1" class="data row1 col1" >(1000, 1500)</td>
#     </tr>
#     <tr>
#       <th id="T_87178_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
hc = create_model('kmeans', num_clusters=100)
plot_model(hc)
